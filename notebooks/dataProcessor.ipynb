# %%
import sys
sys.path.append('/Users/garysimmons/Galvanize/capstones/capstone1/droughtmonitor/src')
import dataProcessor as dp

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df0 = pd.read_csv("../data/CA2020/ca2020D0.csv").set_index('County')
df1 = pd.read_csv("../data/CA2020/ca2020D1.csv").set_index('County')
df2 = pd.read_csv("../data/CA2020/ca2020D2.csv").set_index('County')
df3 = pd.read_csv("../data/CA2020/ca2020D3.csv").set_index('County')
df4 = pd.read_csv("../data/CA2020/ca2020D4.csv").set_index('County')

df0 = df0.rename(columns = {"NonConsecutiveWeeks":"d0"})
df1 = df1.rename(columns = {"NonConsecutiveWeeks":"d1"})
df2 = df2.rename(columns = {"NonConsecutiveWeeks":"d2"})
df3 = df3.rename(columns = {"NonConsecutiveWeeks":"d3"})
df4 = df4.rename(columns = {"NonConsecutiveWeeks":"d4"})

# %%
df0.head()
# Out:
#                   FIPS State  d0
# County
# Alameda County    6001    CA  49
# Alpine County     6003    CA  49
# Amador County     6005    CA  49
# Butte County      6007    CA  49
# Calaveras County  6009    CA  49

# %%
df1.head()
# Out:
#                   FIPS State  d1
# County
# Alameda County    6001    CA  45
# Alpine County     6003    CA  45
# Amador County     6005    CA  45
# Butte County      6007    CA  45
# Calaveras County  6009    CA  45

# %%
df2.head()
# Out:
#                   FIPS State  d2
# County
# Alameda County    6001    CA  37
# Alpine County     6003    CA   4
# Amador County     6005    CA  13
# Butte County      6007    CA  38
# Calaveras County  6009    CA   6

# %%
df3.head()
# Out:
#                   FIPS State  d3
# County
# Butte County      6007    CA  14
# Colusa County     6011    CA  14
# Del Norte County  6015    CA  23
# Glenn County      6021    CA  14
# Humboldt County   6023    CA  37

# %%
df4.head()
# Out:
#                        FIPS State  d4
# County
# Inyo County            6027    CA   3
# San Bernardino County  6071    CA   3

# %%
california2020 = pd.DataFrame(data={"FIPS":df0["FIPS"]})
california2020['d4'] = df4['d4']
california2020 = california2020.replace(np.nan,0)
california2020['d3'] = df3['d3'] - california2020['d4']
california2020 = california2020.replace(np.nan,0)
california2020['d2'] = df2['d2'] - california2020['d3'] - california2020['d4']
california2020 = california2020.replace(np.nan,0)
california2020['d1'] = df1['d1'] - california2020['d2'] - california2020['d3'] - california2020['d4']
california2020 = california2020.replace(np.nan,0)
california2020['d0'] = df0['d0'] - california2020['d1']- california2020['d2'] - california2020['d3'] - california2020['d4']
california2020 = california2020.replace(np.nan,0)
california2020
# Out:
#                         FIPS   d4    d3    d2    d1    d0
# County
# Alameda County          6001  0.0   0.0  37.0   8.0   4.0
# Alpine County           6003  0.0   0.0   4.0  41.0   4.0
# Amador County           6005  0.0   0.0  13.0  32.0   4.0
# Butte County            6007  0.0  14.0  24.0   7.0   4.0
# Calaveras County        6009  0.0   0.0   6.0  39.0   4.0
# Colusa County           6011  0.0  14.0  24.0   7.0   4.0
# Contra Costa County     6013  0.0   0.0  37.0   8.0   4.0
# Del Norte County        6015  0.0  23.0  19.0   2.0   1.0
# El Dorado County        6017  0.0   0.0   4.0  41.0   4.0
# Fresno County           6019  0.0   0.0   6.0  41.0   2.0
# Glenn County            6021  0.0  14.0  24.0   7.0   4.0
# Humboldt County         6023  0.0  37.0   1.0   6.0   2.0
# Imperial County         6025  0.0   3.0   3.0  10.0   4.0
# Inyo County             6027  3.0   5.0   8.0  31.0   2.0
# Kern County             6029  0.0   3.0   1.0  13.0  14.0
# Kings County            6031  0.0   0.0   4.0  11.0  34.0
# Lake County             6033  0.0  14.0  24.0   7.0   4.0
# Lassen County           6035  0.0  14.0   5.0  25.0   9.0
# Los Angeles County      6037  0.0   0.0   3.0   3.0  19.0
# Madera County           6039  0.0   0.0   6.0  41.0   2.0
# Marin County            6041  0.0   0.0  37.0   7.0   5.0
# Mariposa County         6043  0.0   0.0   6.0  41.0   2.0
# Mendocino County        6045  0.0  14.0  24.0   7.0   1.0
# Merced County           6047  0.0   0.0   6.0  41.0   2.0
# Modoc County            6049  0.0  24.0   1.0  20.0   8.0
# Mono County             6051  0.0   3.0  13.0  31.0   2.0
# Monterey County         6053  0.0   0.0   0.0   6.0  43.0
# Napa County             6055  0.0  14.0  23.0   8.0   4.0
# Nevada County           6057  0.0   0.0  37.0   8.0   4.0
# Orange County           6059  0.0   0.0   0.0   5.0   9.0
# Placer County           6061  0.0   0.0  37.0   8.0   4.0
# Plumas County           6063  0.0   0.0  19.0  26.0   2.0
# Riverside County        6065  0.0   3.0   5.0  11.0   7.0
# Sacramento County       6067  0.0  14.0  23.0   8.0   4.0
# San Benito County       6069  0.0   0.0   0.0  25.0  24.0
# San Bernardino County   6071  3.0   5.0  11.0   1.0   6.0
# San Diego County        6073  0.0   0.0   0.0  16.0   8.0
# San Francisco County    6075  0.0   0.0  37.0   7.0   5.0
# San Joaquin County      6077  0.0   0.0  37.0   8.0   4.0
# San Luis Obispo County  6079  0.0   0.0   0.0  10.0   5.0
# San Mateo County        6081  0.0   0.0  37.0   7.0   5.0
# Santa Barbara County    6083  0.0   0.0   0.0   6.0   9.0
# Santa Clara County      6085  0.0   0.0  33.0  11.0   5.0
# Santa Cruz County       6087  0.0   0.0   0.0  44.0   5.0
# Shasta County           6089  0.0  37.0   1.0   6.0   2.0
# Sierra County           6091  0.0   0.0  19.0  26.0   4.0
# Siskiyou County         6093  0.0  37.0   5.0   3.0   8.0
# Solano County           6095  0.0  14.0  23.0   8.0   4.0
# Sonoma County           6097  0.0  14.0  23.0   8.0   4.0
# Stanislaus County       6099  0.0   0.0   6.0  39.0   4.0
# Sutter County           6101  0.0  14.0  23.0   8.0   4.0
# Tehama County           6103  0.0  14.0  24.0   7.0   4.0
# Trinity County          6105  0.0  37.0   1.0   7.0   1.0
# Tulare County           6107  0.0   0.0   6.0  41.0   2.0
# Tuolumne County         6109  0.0   0.0   6.0  41.0   2.0
# Ventura County          6111  0.0   0.0   0.0   6.0   9.0
# Yolo County             6113  0.0  14.0  23.0   8.0   4.0
# Yuba County             6115  0.0  14.0  23.0   8.0   4.0

# %%
consec0 = pd.read_csv("../data/CA2020/d0Consecutive.csv")
consec1 = pd.read_csv("../data/CA2020/d1Consecutive.csv")
consec2 = pd.read_csv("../data/CA2020/d2Consecutive.csv")
consec3 = pd.read_csv("../data/CA2020/d3Consecutive.csv")
consec4 = pd.read_csv("../data/CA2020/d4Consecutive.csv")

# %%
consec0['DCat']=0
consec1['DCat']=1
consec2['DCat']=2
consec3['DCat']=3
consec4['DCat']=4
consecCA2020 = pd.concat([consec0,consec1,consec2,consec3,consec4]).sort_values(by=["County","StartDate"])

# %%
consecCA2020[consecCA2020["County"]=="Inyo County"]
# Out:
#     FIPS   StartDate     EndDate  ConsecutiveWeeks State       County  DCat
# 13  6027  2020-01-30  2020-12-31                49    CA  Inyo County     0
# 13  6027  2020-02-13  2020-12-31                47    CA  Inyo County     1
# 13  6027  2020-09-17  2020-12-31                16    CA  Inyo County     2
# 7   6027  2020-11-12  2020-12-31                 8    CA  Inyo County     3
# 0   6027  2020-12-17  2020-12-31                 3    CA  Inyo County     4

# %%
fig,ax = plt.subplots()
ax.fill_between([])
